# %%
import os
import random
import shutil
import csv
import cv2
import itertools
import numpy as np
import pandas as pd
import sys
import tempfile
import tqdm
import time

from matplotlib import pyplot as plt
from matplotlib.collections import LineCollection

import tensorflow as tf
import tensorflow_hub as hub
from tensorflow import keras
from PIL import Image
from sklearn.model_selection import train_test_split
from sklearn.metrics import accuracy_score, classification_report, confusion_matrix

# %%
pose_sample_rpi_path = os.path.join(os.getcwd(), 'examples/lite/examples/pose_estimation/raspberry_pi')
sys.path.append(pose_sample_rpi_path)

# %%
import utils
from data import BodyPart
from ml import Movenet
movenet = Movenet('movenet_thunder')

# %%
def detect(input_tensor, inference_count=3):
  """Runs detection on an input image.
  Args:
    input_tensor: A [height, width, 3] Tensor of type tf.float32.
      Note that height and width can be anything since the image will be
      immediately resized according to the needs of the model within this
      function.
    inference_count: Number of times the model should run repeatly on the
      same input image to improve detection accuracy.

  Returns:
    A Person entity detected
  """
  channel,image_height, image_width = input_tensor.shape

  # Detect pose using the full input image
  movenet.detect(input_tensor.numpy(), reset_crop_region=True)

  # Repeatedly using previous detection result to identify the region of
  # interest and only croping that region to improve detection accuracy
  for _ in range(inference_count - 1):
    person = movenet.detect(input_tensor.numpy(),
                            reset_crop_region=False)

  return person

# %%
def draw_prediction_on_image(
    image, person, crop_region=None, close_figure=True,
    keep_input_size=False):
  """Draws the keypoint predictions on image.

  Args:
    image: An numpy array with shape [height, width, channel] representing the
      pixel values of the input image.
    person: A person entity returned from the MoveNet.SinglePose model.
    close_figure: Whether to close the plt figure after the function returns.
    keep_input_size: Whether to keep the size of the input image.

  Returns:
    An numpy array with shape [out_height, out_width, channel] representing the
    image overlaid with keypoint predictions.
  """
  # Draw the detection result on top of the image.
  image_np = utils.visualize(image, [person])

  # Plot the image with detection results.
  height, width, channel = image.shape
  aspect_ratio = float(width) / height
  fig, ax = plt.subplots(figsize=(12 * aspect_ratio, 12))
  im = ax.imshow(image_np)

  if close_figure:
    plt.close(fig)

  if not keep_input_size:
    image_np = utils.keep_aspect_ratio_resizer(image_np, (512, 512))

  return image_np

# %%
class MoveNetPreprocessor(object):
  """Helper class to preprocess pose sample images for classification."""

  def __init__(self,
               images_in_folder,
               images_out_folder,
               csvs_out_path):
    """Creates a preprocessor to detection pose from images and save as CSV.

    Args:
      images_in_folder: Path to the folder with the input images. It should
        follow this structure:
        Traffic police hand gestures
        |__ Pose1
            |______ 00000128.jpg
            |______ 00000181.bmp
            |______ ...
        |__ Pose2
            |______ 00000243.jpg
            |______ 00000306.jpg
            |______ ...
        ...
      images_out_folder: Path to write the images overlay with detected
        landmarks. These images are useful when you need to debug accuracy
        issues.
      csvs_out_path: Path to write the CSV containing the detected landmark
        coordinates and label of each image that can be used to train a pose
        classification model.
    """
    self._images_in_folder = images_in_folder
    self._images_out_folder = images_out_folder
    self._csvs_out_path = csvs_out_path
    self._messages = []

    # Create a temp dir to store the pose CSVs per class
    self._csvs_out_folder_per_class = tempfile.mkdtemp()

    # Get list of pose classes and print image statistics
    self._pose_class_names = sorted(
        [n for n in os.listdir(self._images_in_folder) if not n.startswith('.')]
        )

  def detectFaces(self,face_cascade,image,flipped):
    gray = cv2.cvtColor(image.numpy(), cv2.COLOR_BGR2GRAY)
    faces = face_cascade.detectMultiScale(gray, 1.1, 4)
    if(flipped):
      if(len(faces)==0):
        return 1
      return 0
    else:
      if(len(faces)==0):
        return 0
      return 1
      
  # def detectFaces(self,face_cascade,image):
  #   gray = cv2.cvtColor(image.numpy(), cv2.COLOR_BGR2GRAY)
  #   faces = face_cascade.detectMultiScale(gray, 1.1, 4)
  #   if(len(faces)==0):
  #     return 0
  #   return 1
  
  
  def process(self, per_pose_class_limit=None, detection_threshold=0.1):
    """Preprocesses images in the given folder.
    Args:
      per_pose_class_limit: Number of images to load. As preprocessing usually
        takes time, this parameter can be specified to make the reduce of the
        dataset for testing.
      detection_threshold: Only keep images with all landmark confidence score
        above this threshold.
    """
    # Loop through the classes and preprocess its images
    for pose_class_name in self._pose_class_names:
      print('Preprocessing', pose_class_name, file=sys.stderr)

      # Paths for the pose class.
      images_in_folder = os.path.join(self._images_in_folder, pose_class_name)
      images_out_folder = os.path.join(self._images_out_folder, pose_class_name)
      csv_out_path = os.path.join(self._csvs_out_folder_per_class,
                                  pose_class_name + '.csv')
      if not os.path.exists(images_out_folder):
        os.makedirs(images_out_folder)

      # Detect landmarks in each image and write it to a CSV file
      with open(csv_out_path, 'w') as csv_out_file:
        csv_out_writer = csv.writer(csv_out_file, 
                                    delimiter=',', 
                                    quoting=csv.QUOTE_MINIMAL)
        # Get list of images
        image_names = sorted(
            [n for n in os.listdir(images_in_folder) if not n.startswith('.')])
        if per_pose_class_limit is not None:
          image_names = image_names[:per_pose_class_limit]

        valid_image_count = 0

        # Detect pose landmarks from each image
        face_cascade = cv2.CascadeClassifier('haarcascade_frontalface_default.xml')
        for image_name in tqdm.tqdm(image_names):
          image_path = os.path.join(images_in_folder, image_name)

          try:
            image = tf.io.read_file(image_path)
            image = tf.io.decode_jpeg(image)
          except:
            self._messages.append('Skipped ' + image_path + '. Invalid image.')
            continue
          else:
            image = tf.io.read_file(image_path)
            image = tf.io.decode_jpeg(image)
            image_height, image_width, channel = image.shape

          # Skip images that isn't RGB because Movenet requires RGB images
          if channel != 3:
            self._messages.append('Skipped ' + image_path +
                                  '. Image isn\'t in RGB format.')
            continue
          person = detect(image)
          if image_name.startswith("flipped_"):
            flipped = True
          else:
            flipped = False
          faces = self.detectFaces(face_cascade,image,flipped)
          # Save landmarks if all landmarks were detected
          min_landmark_score = min(
              [keypoint.score for keypoint in person.keypoints])
          should_keep_image = min_landmark_score >= detection_threshold
          if not should_keep_image:
            self._messages.append('Skipped ' + image_path +
                                  '. No pose was confidentlly detected.')
            continue

          valid_image_count += 1

          # Draw the prediction result on top of the image for debugging later
          output_overlay = draw_prediction_on_image(
              image.numpy().astype(np.uint8), person, 
              close_figure=True, keep_input_size=True)

          # Write detection result into an image file
          output_frame = cv2.cvtColor(output_overlay, cv2.COLOR_RGB2BGR)
          cv2.imwrite(os.path.join(images_out_folder, image_name), output_frame)

          # Get landmarks and scale it to the same size as the input image
          pose_landmarks = np.array(
              [[keypoint.coordinate.x, keypoint.coordinate.y, keypoint.score]
                for keypoint in person.keypoints],
              dtype=np.float32)

          # Write the landmark coordinates to its per-class CSV file
          coordinates = pose_landmarks.flatten().astype(str).tolist()
          # coordinates = pose_landmarks.flatten().astype(np.str).tolist()
          csv_out_writer.writerow([image_name] +[faces]+ [faces]+[faces]+coordinates)

        if not valid_image_count:
          raise RuntimeError(
              'No valid images found for the "{}" class.'
              .format(pose_class_name))

    # Print the error message collected during preprocessing.
    print('\n'.join(self._messages))

    # Combine all per-class CSVs into a single output file
    all_landmarks_df = self._all_landmarks_as_dataframe()
    all_landmarks_df.to_csv(self._csvs_out_path, index=False)

  def class_names(self):
    """List of classes found in the training dataset."""
    return self._pose_class_names
  
    
  def _all_landmarks_as_dataframe(self):
    """Merge all per-class CSVs into a single dataframe."""
    total_df = None
    for class_index, class_name in enumerate(self._pose_class_names):
      csv_out_path = os.path.join(self._csvs_out_folder_per_class,
                                  class_name + '.csv')
      per_class_df = pd.read_csv(csv_out_path, header=None)

      # Add the labels
      per_class_df['class_no'] = [class_index]*len(per_class_df)
      per_class_df['class_name'] = [class_name]*len(per_class_df)

      # Append the folder name to the filename column (first column)
      per_class_df[per_class_df.columns[0]] = (os.path.join(class_name, '') 
        + per_class_df[per_class_df.columns[0]].astype(str))

      if total_df is None:
        # For the first class, assign its data to the total dataframe
        total_df = per_class_df
      else:
        # Concatenate each class's data into the total dataframe
        total_df = pd.concat([total_df, per_class_df], axis=0)

    list_name = [[bodypart.name + '_x', bodypart.name + '_y', 
                  bodypart.name + '_score'] for bodypart in BodyPart] 
    header_name = []
    for columns_name in list_name:
      header_name += columns_name
    header_name = ['file_name'] +['Face_orientation_1']+['Face_orientation_2']+['Face_orientation_3']+ header_name
    header_map = {total_df.columns[i]: header_name[i] 
                  for i in range(len(header_name))}

    total_df.rename(header_map, axis=1, inplace=True)
    # add one more column for the class name
    # It will be first column, and the name will be Facing front

    return total_df

# %%
def processTensorImage(path):
    if(type(path) == str):
        image = tf.io.read_file(path)
        image = tf.image.decode_jpeg(image)
    else:
        image = tf.convert_to_tensor(path, dtype=tf.float32)
    return image

def convertTensorImageToNumpy(image):
    image = image.numpy()
    return image


# def processTensorImageFromNumpy(image):
#     image = tf.convert_to_tensor(image, dtype=tf.float32)
#     return image

# %%
use_custom_dataset = True
is_skip_step_1 = False
dataset_is_split = False

# %%
def split_into_train_test(images_origin, images_dest, test_split):
  """Splits a directory of sorted images into training and test sets.

  Args:
    images_origin: Path to the directory with your images. This directory
      must include subdirectories for each of your labeled classes. For example:
      Traffic_police_gestures/
      |__ Pose1/
          |______ 00000128.jpg
          |______ 00000181.jpg
          |______ ...
      |__ Pose2/
          |______ 00000243.jpg
          |______ 00000306.jpg
          |______ ...
      ...
    images_dest: Path to a directory where you want the split dataset to be
      saved. The results looks like this:
      split_yoga_poses/
      |__ train/
          |__ Pose1/
              |______ 00000128.jpg
              |______ ...
      |__ test/
          |__ Pose1/
              |______ 00000181.jpg
              |______ ...
    test_split: Fraction of data to reserve for test (float between 0 and 1).
  """
  _, dirs, _ = next(os.walk(images_origin))

  TRAIN_DIR = os.path.join(images_dest, 'train')
  TEST_DIR = os.path.join(images_dest, 'test')
  os.makedirs(TRAIN_DIR, exist_ok=True)
  os.makedirs(TEST_DIR, exist_ok=True)

  for dir in dirs:
    # Get all filenames for this dir, filtered by filetype
    filenames = os.listdir(os.path.join(images_origin, dir))
    filenames = [os.path.join(images_origin, dir, f) for f in filenames if (
        f.endswith('.png') or f.endswith('.jpg') or f.endswith('.jpeg') or f.endswith('.bmp'))]
    # Shuffle the files, deterministically
    filenames.sort()
    random.seed(42)
    random.shuffle(filenames)
    # Divide them into train/test dirs
    os.makedirs(os.path.join(TEST_DIR, dir), exist_ok=True)
    os.makedirs(os.path.join(TRAIN_DIR, dir), exist_ok=True)
    test_count = int(len(filenames) * test_split)
    for i, file in enumerate(filenames):
      if i < test_count:
        destination = os.path.join(TEST_DIR, dir, os.path.split(file)[1])
      else:
        destination = os.path.join(TRAIN_DIR, dir, os.path.split(file)[1])
      shutil.copyfile(file, destination)
    print(
        f'Moved {test_count} of {len(filenames)} from class "{dir}" into test.')
  print(f'Your split dataset is in "{images_dest}"')

# %%
dataset_in = 'Dataset'

if not os.path.isdir(dataset_in):
   raise Exception("Dataset_in is not a valid directory")
dataset_out = f'split_{dataset_in}'
if not os.path.isdir(dataset_out):
   split_into_train_test(dataset_in, dataset_out, test_split=0.2)
IMAGES_ROOT = dataset_out
# Out:
# Moved 52 of 262 from class "NoPose" into test.
# Moved 238 of 1190 from class "Pose1" into test.
# Moved 221 of 1108 from class "Pose2" into test.
# Moved 219 of 1096 from class "Pose3" into test.
# Moved 216 of 1082 from class "Pose4" into test.
# Moved 196 of 984 from class "Pose5" into test.
# Moved 158 of 794 from class "Pose6" into test.
# Moved 228 of 1142 from class "Pose7" into test.
# Your split dataset is in "split_Dataset"

# %%
# if not os.path.isdir(IMAGES_ROOT):

images_in_train_folder = os.path.join(IMAGES_ROOT, 'train')
images_out_train_folder = 'poses_images_out_train'
csvs_out_train_path = 'train_data.csv'

if not os.path.isdir(images_out_train_folder):
    preprocessor = MoveNetPreprocessor(
        images_in_folder=images_in_train_folder,
        images_out_folder=images_out_train_folder,
        csvs_out_path=csvs_out_train_path,
    )
    
    preprocessor.process(per_pose_class_limit=None, detection_threshold=0)
# Out:
# Preprocessing NoPose
# 100%|██████████| 210/210 [01:18<00:00,  2.69it/s]
# Preprocessing Pose1
# 100%|██████████| 952/952 [06:00<00:00,  2.64it/s]
# Preprocessing Pose2
# 100%|██████████| 887/887 [05:58<00:00,  2.47it/s]
# Preprocessing Pose3
# 100%|██████████| 877/877 [05:42<00:00,  2.56it/s]
# Preprocessing Pose4
# 100%|██████████| 866/866 [05:32<00:00,  2.60it/s]
# Preprocessing Pose5
# 100%|██████████| 788/788 [04:41<00:00,  2.80it/s]
# Preprocessing Pose6
# 100%|██████████| 636/636 [03:38<00:00,  2.92it/s]
# Preprocessing Pose7
# 100%|██████████| 914/914 [05:22<00:00,  2.83it/s]

# %%
images_in_test_folder = os.path.join(IMAGES_ROOT, 'test')
images_out_test_folder = 'poses_images_out_test'
csvs_out_test_path = 'test_data.csv'
if not os.path.isdir(images_out_test_folder):
    preprocessor = MoveNetPreprocessor(
        images_in_folder=images_in_test_folder,
        images_out_folder=images_out_test_folder,
        csvs_out_path=csvs_out_test_path,
    )
    preprocessor.process(per_pose_class_limit=None, detection_threshold=0)
# Out:
# Preprocessing NoPose
# 100%|██████████| 52/52 [00:18<00:00,  2.76it/s]
# Preprocessing Pose1
# 100%|██████████| 238/238 [01:22<00:00,  2.90it/s]
# Preprocessing Pose2
# 100%|██████████| 221/221 [01:20<00:00,  2.75it/s]
# Preprocessing Pose3
# 100%|██████████| 219/219 [01:32<00:00,  2.36it/s]
# Preprocessing Pose4
# 100%|██████████| 216/216 [01:19<00:00,  2.73it/s]
# Preprocessing Pose5
# 100%|██████████| 196/196 [01:09<00:00,  2.84it/s]
# Preprocessing Pose6
# 100%|██████████| 158/158 [00:53<00:00,  2.93it/s]
# Preprocessing Pose7
# 100%|██████████| 228/228 [01:21<00:00,  2.80it/s]

# %%
def load_pose_landmarks(csv_path):
  """Loads a CSV created by MoveNetPreprocessor.
  Returns:
    X: Detected landmark coordinates and scores of shape (N, 18 * 3)
    y: Ground truth labels of shape (N, label_count)
    classes: The list of all class names found in the dataset
    dataframe: The CSV loaded as a Pandas dataframe features (X) and ground
      truth labels (y) to use later to train a pose classification model.
  """

  # Load the CSV file
  dataframe = pd.read_csv(csv_path)
  df_to_process = dataframe.copy()

  # Drop the file_name columns as you don't need it during training.
  df_to_process.drop(columns=['file_name'], inplace=True)

  # Extract the list of class names
  classes = df_to_process.pop('class_name').unique()

  # Extract the labels
  y = df_to_process.pop('class_no')

  # Convert the input features and labels into the correct format for training.
  X = df_to_process.astype('float64')
  y = keras.utils.to_categorical(y)

  return X, y, classes, dataframe

# %%
# Load the train data
X, y, class_names, _ = load_pose_landmarks(csvs_out_train_path)

# Split training data (X, y) into (X_train, y_train) and (X_val, y_val)
X_train, X_val, y_train, y_val = train_test_split(X, y,
                                                  test_size=0.15)

# %%
# Load the test data
X_test, y_test, _, df_test = load_pose_landmarks(csvs_out_test_path)

# %%
def get_center_point(landmarks, left_bodypart, right_bodypart):
  """Calculates the center point of the two given landmarks."""

  left = tf.gather(landmarks, left_bodypart.value, axis=1)
  right = tf.gather(landmarks, right_bodypart.value, axis=1)
  center = left * 0.5 + right * 0.5
  return center


def get_pose_size(landmarks, torso_size_multiplier=2.5):
  """Calculates pose size.

  It is the maximum of two values:
    * Torso size multiplied by `torso_size_multiplier`
    * Maximum distance from pose center to any pose landmark
  """
  # Hips center
  hips_center = get_center_point(landmarks, BodyPart.LEFT_HIP,
                                 BodyPart.RIGHT_HIP)

  # Shoulders center
  shoulders_center = get_center_point(landmarks, BodyPart.LEFT_SHOULDER,
                                      BodyPart.RIGHT_SHOULDER)

  # Torso size as the minimum body size
  torso_size = tf.linalg.norm(shoulders_center - hips_center)

  # Pose center
  pose_center_new = get_center_point(landmarks, BodyPart.LEFT_HIP,
                                     BodyPart.RIGHT_HIP)
  pose_center_new = tf.expand_dims(pose_center_new, axis=1)
  # Broadcast the pose center to the same size as the landmark vector to
  # perform substraction
  pose_center_new = tf.broadcast_to(pose_center_new,[tf.size(landmarks) // (18*2), 18, 2])

  # Dist to pose center
  d = tf.gather(landmarks - pose_center_new, 0, axis=0,
                name="dist_to_pose_center")
  # Max dist to pose center
  max_dist = tf.reduce_max(tf.linalg.norm(d, axis=0))

  # Normalize scale
  pose_size = tf.maximum(torso_size * torso_size_multiplier, max_dist)

  return pose_size


def normalize_pose_landmarks(landmarks):
  """Normalizes the landmarks translation by moving the pose center to (0,0) and
  scaling it to a constant pose size.
  """
  # Move landmarks so that the pose center becomes (0,0)
  pose_center = get_center_point(landmarks, BodyPart.LEFT_HIP,
                                 BodyPart.RIGHT_HIP)
  pose_center = tf.expand_dims(pose_center, axis=1)
  # Broadcast the pose center to the same size as the landmark vector to perform
  # substraction
  pose_center = tf.broadcast_to(pose_center,
                                [tf.size(landmarks) // (18*2), 18, 2])
  landmarks = landmarks - pose_center

  # Scale the landmarks to a constant pose size
  pose_size = get_pose_size(landmarks)
  landmarks /= pose_size

  return landmarks


def landmarks_to_embedding(landmarks_and_scores):
  """Converts the input landmarks into a pose embedding."""
  # Reshape the flat input into a matrix with shape=(18, 3)
  reshaped_inputs = keras.layers.Reshape((18, 3))(landmarks_and_scores)
  # Normalize landmarks 2D
  landmarks = normalize_pose_landmarks(reshaped_inputs[:, :, :2])
  # Flatten the normalized landmark coordinates into a vector
  embedding = keras.layers.Flatten()(landmarks)
  return embedding

# %%
# Define the model
inputs = tf.keras.Input(shape=(54))
embedding = landmarks_to_embedding(inputs)

layer = keras.layers.Dense(128, activation=tf.nn.relu6)(embedding)
layer = keras.layers.Dropout(0.5)(layer)
layer = keras.layers.Dense(64, activation=tf.nn.relu6)(layer)
layer = keras.layers.Dropout(0.5)(layer)
outputs = keras.layers.Dense(len(class_names), activation="softmax")(layer)

model = keras.Model(inputs, outputs)
model.summary()
# Out:
# Model: "model"
# __________________________________________________________________________________________________
#  Layer (type)                   Output Shape         Param #     Connected to
# ==================================================================================================
#  input_1 (InputLayer)           [(None, 54)]         0           []
#
#  reshape (Reshape)              (None, 18, 3)        0           ['input_1[0][0]']
#
#  tf.__operators__.getitem (Slic  (None, 18, 2)       0           ['reshape[0][0]']
#  ingOpLambda)
#
#  tf.compat.v1.gather (TFOpLambd  (None, 2)           0           ['tf.__operators__.getitem[0][0]'
#  a)                                                              ]
#
#  tf.compat.v1.gather_1 (TFOpLam  (None, 2)           0           ['tf.__operators__.getitem[0][0]'
#  bda)                                                            ]
#
#  tf.math.multiply (TFOpLambda)  (None, 2)            0           ['tf.compat.v1.gather[0][0]']
#
#  tf.math.multiply_1 (TFOpLambda  (None, 2)           0           ['tf.compat.v1.gather_1[0][0]']
#  )
#
#  tf.__operators__.add (TFOpLamb  (None, 2)           0           ['tf.math.multiply[0][0]',
#  da)                                                              'tf.math.multiply_1[0][0]']
#
#  tf.compat.v1.size (TFOpLambda)  ()                  0           ['tf.__operators__.getitem[0][0]'
#                                                                  ]
#
#  tf.expand_dims (TFOpLambda)    (None, 1, 2)         0           ['tf.__operators__.add[0][0]']
#
#  tf.compat.v1.floor_div (TFOpLa  ()                  0           ['tf.compat.v1.size[0][0]']
#  mbda)
#
#  tf.broadcast_to (TFOpLambda)   (None, 18, 2)        0           ['tf.expand_dims[0][0]',
#                                                                   'tf.compat.v1.floor_div[0][0]']
#
#  tf.math.subtract (TFOpLambda)  (None, 18, 2)        0           ['tf.__operators__.getitem[0][0]'
#                                                                  , 'tf.broadcast_to[0][0]']
#
#  tf.compat.v1.gather_6 (TFOpLam  (None, 2)           0           ['tf.math.subtract[0][0]']
#  bda)
#
#  tf.compat.v1.gather_7 (TFOpLam  (None, 2)           0           ['tf.math.subtract[0][0]']
#  bda)
#
#  tf.math.multiply_6 (TFOpLambda  (None, 2)           0           ['tf.compat.v1.gather_6[0][0]']
#  )
#
#  tf.math.multiply_7 (TFOpLambda  (None, 2)           0           ['tf.compat.v1.gather_7[0][0]']
#  )
#
#  tf.__operators__.add_3 (TFOpLa  (None, 2)           0           ['tf.math.multiply_6[0][0]',
#  mbda)                                                            'tf.math.multiply_7[0][0]']
#
#  tf.compat.v1.size_1 (TFOpLambd  ()                  0           ['tf.math.subtract[0][0]']
#  a)
#
#  tf.compat.v1.gather_4 (TFOpLam  (None, 2)           0           ['tf.math.subtract[0][0]']
#  bda)
#
#  tf.compat.v1.gather_5 (TFOpLam  (None, 2)           0           ['tf.math.subtract[0][0]']
#  bda)
#
#  tf.compat.v1.gather_2 (TFOpLam  (None, 2)           0           ['tf.math.subtract[0][0]']
#  bda)
#
#  tf.compat.v1.gather_3 (TFOpLam  (None, 2)           0           ['tf.math.subtract[0][0]']
#  bda)
#
#  tf.expand_dims_1 (TFOpLambda)  (None, 1, 2)         0           ['tf.__operators__.add_3[0][0]']
#
#  tf.compat.v1.floor_div_1 (TFOp  ()                  0           ['tf.compat.v1.size_1[0][0]']
#  Lambda)
#
#  tf.math.multiply_4 (TFOpLambda  (None, 2)           0           ['tf.compat.v1.gather_4[0][0]']
#  )
#
#  tf.math.multiply_5 (TFOpLambda  (None, 2)           0           ['tf.compat.v1.gather_5[0][0]']
#  )
#
#  tf.math.multiply_2 (TFOpLambda  (None, 2)           0           ['tf.compat.v1.gather_2[0][0]']
#  )
#
#  tf.math.multiply_3 (TFOpLambda  (None, 2)           0           ['tf.compat.v1.gather_3[0][0]']
#  )
#
#  tf.broadcast_to_1 (TFOpLambda)  (None, 18, 2)       0           ['tf.expand_dims_1[0][0]',
#                                                                   'tf.compat.v1.floor_div_1[0][0]'
#                                                                  ]
#
#  tf.__operators__.add_2 (TFOpLa  (None, 2)           0           ['tf.math.multiply_4[0][0]',
#  mbda)                                                            'tf.math.multiply_5[0][0]']
#
#  tf.__operators__.add_1 (TFOpLa  (None, 2)           0           ['tf.math.multiply_2[0][0]',
#  mbda)                                                            'tf.math.multiply_3[0][0]']
#
#  tf.math.subtract_2 (TFOpLambda  (None, 18, 2)       0           ['tf.math.subtract[0][0]',
#  )                                                                'tf.broadcast_to_1[0][0]']
#
#  tf.math.subtract_1 (TFOpLambda  (None, 2)           0           ['tf.__operators__.add_2[0][0]',
#  )                                                                'tf.__operators__.add_1[0][0]']
#
#  tf.compat.v1.gather_8 (TFOpLam  (18, 2)             0           ['tf.math.subtract_2[0][0]']
#  bda)
#
#  tf.compat.v1.norm (TFOpLambda)  ()                  0           ['tf.math.subtract_1[0][0]']
#
#  tf.compat.v1.norm_1 (TFOpLambd  (2,)                0           ['tf.compat.v1.gather_8[0][0]']
#  a)
#
#  tf.math.multiply_8 (TFOpLambda  ()                  0           ['tf.compat.v1.norm[0][0]']
#  )
#
#  tf.math.reduce_max (TFOpLambda  ()                  0           ['tf.compat.v1.norm_1[0][0]']
#  )
#
#  tf.math.maximum (TFOpLambda)   ()                   0           ['tf.math.multiply_8[0][0]',
#                                                                   'tf.math.reduce_max[0][0]']
#
#  tf.math.truediv (TFOpLambda)   (None, 18, 2)        0           ['tf.math.subtract[0][0]',
#                                                                   'tf.math.maximum[0][0]']
#
#  flatten (Flatten)              (None, 36)           0           ['tf.math.truediv[0][0]']
#
#  dense (Dense)                  (None, 128)          4736        ['flatten[0][0]']
#
#  dropout (Dropout)              (None, 128)          0           ['dense[0][0]']
#
#  dense_1 (Dense)                (None, 64)           8256        ['dropout[0][0]']
#
#  dropout_1 (Dropout)            (None, 64)           0           ['dense_1[0][0]']
#
#  dense_2 (Dense)                (None, 8)            520         ['dropout_1[0][0]']
#
# ==================================================================================================
# Total params: 13,512
# Trainable params: 13,512
# Non-trainable params: 0
# __________________________________________________________________________________________________

# %%
model.compile(
    optimizer='adam',
    loss='categorical_crossentropy',
    metrics=['accuracy']
)

# Add a checkpoint callback to store the checkpoint that has the highest
# validation accuracy.
checkpoint_path = "weights.best.hdf5"
checkpoint = keras.callbacks.ModelCheckpoint(checkpoint_path,
                                             monitor='val_accuracy',
                                             verbose=1,
                                             save_best_only=True,
                                             mode='max')
earlystopping = keras.callbacks.EarlyStopping(monitor='val_accuracy',
                                              patience=20)

# Start training
history = model.fit(X_train, y_train,
                    epochs=200,
                    batch_size=16,
                    validation_data=(X_val, y_val),
                    callbacks=[checkpoint, earlystopping])
# Out:
# Epoch 1/200
# 313/326 [===========================>..] - ETA: 0s - loss: 1.9206 - accuracy: 0.2476
# Epoch 1: val_accuracy improved from -inf to 0.46630, saving model to weights.best.hdf5
# 326/326 [==============================] - 3s 7ms/step - loss: 1.9126 - accuracy: 0.2520 - val_loss: 1.6228 - val_accuracy: 0.4663
# Epoch 2/200
# 326/326 [==============================] - ETA: 0s - loss: 1.5081 - accuracy: 0.4428
# Epoch 2: val_accuracy improved from 0.46630 to 0.64348, saving model to weights.best.hdf5
# 326/326 [==============================] - 1s 2ms/step - loss: 1.5081 - accuracy: 0.4428 - val_loss: 1.2117 - val_accuracy: 0.6435
# Epoch 3/200
# 305/326 [===========================>..] - ETA: 0s - loss: 1.2833 - accuracy: 0.5227
# Epoch 3: val_accuracy improved from 0.64348 to 0.69565, saving model to weights.best.hdf5
# 326/326 [==============================] - 1s 2ms/step - loss: 1.2735 - accuracy: 0.5269 - val_loss: 1.0124 - val_accuracy: 0.6957
# Epoch 4/200
# 321/326 [============================>.] - ETA: 0s - loss: 1.1504 - accuracy: 0.5905
# Epoch 4: val_accuracy did not improve from 0.69565
# 326/326 [==============================] - 1s 2ms/step - loss: 1.1493 - accuracy: 0.5914 - val_loss: 0.9124 - val_accuracy: 0.6891
# Epoch 5/200
# 302/326 [==========================>...] - ETA: 0s - loss: 1.0664 - accuracy: 0.6242
# Epoch 5: val_accuracy improved from 0.69565 to 0.73370, saving model to weights.best.hdf5
# 326/326 [==============================] - 1s 2ms/step - loss: 1.0621 - accuracy: 0.6259 - val_loss: 0.8416 - val_accuracy: 0.7337
# Epoch 6/200
# 307/326 [===========================>..] - ETA: 0s - loss: 0.9780 - accuracy: 0.6582
# Epoch 6: val_accuracy improved from 0.73370 to 0.76304, saving model to weights.best.hdf5
# 326/326 [==============================] - 1s 2ms/step - loss: 0.9814 - accuracy: 0.6557 - val_loss: 0.8030 - val_accuracy: 0.7630
# Epoch 7/200
# 303/326 [==========================>...] - ETA: 0s - loss: 0.9479 - accuracy: 0.6739
# Epoch 7: val_accuracy did not improve from 0.76304
# 326/326 [==============================] - 1s 2ms/step - loss: 0.9407 - accuracy: 0.6754 - val_loss: 0.7534 - val_accuracy: 0.7576
# Epoch 8/200
# 316/326 [============================>.] - ETA: 0s - loss: 0.8888 - accuracy: 0.6952
# Epoch 8: val_accuracy improved from 0.76304 to 0.76522, saving model to weights.best.hdf5
# 326/326 [==============================] - 1s 2ms/step - loss: 0.8898 - accuracy: 0.6946 - val_loss: 0.7105 - val_accuracy: 0.7652
# Epoch 9/200
# 321/326 [============================>.] - ETA: 0s - loss: 0.8778 - accuracy: 0.7005
# Epoch 9: val_accuracy improved from 0.76522 to 0.78152, saving model to weights.best.hdf5
# 326/326 [==============================] - 1s 2ms/step - loss: 0.8757 - accuracy: 0.7010 - val_loss: 0.6834 - val_accuracy: 0.7815
# Epoch 10/200
# 302/326 [==========================>...] - ETA: 0s - loss: 0.8562 - accuracy: 0.7063
# Epoch 10: val_accuracy improved from 0.78152 to 0.78370, saving model to weights.best.hdf5
# 326/326 [==============================] - 1s 2ms/step - loss: 0.8534 - accuracy: 0.7060 - val_loss: 0.6680 - val_accuracy: 0.7837
# Epoch 11/200
# 320/326 [============================>.] - ETA: 0s - loss: 0.8241 - accuracy: 0.7193
# Epoch 11: val_accuracy did not improve from 0.78370
# 326/326 [==============================] - 1s 2ms/step - loss: 0.8217 - accuracy: 0.7203 - val_loss: 0.6529 - val_accuracy: 0.7837
# Epoch 12/200
# 323/326 [============================>.] - ETA: 0s - loss: 0.8098 - accuracy: 0.7330
# Epoch 12: val_accuracy improved from 0.78370 to 0.79674, saving model to weights.best.hdf5
# 326/326 [==============================] - 1s 2ms/step - loss: 0.8091 - accuracy: 0.7328 - val_loss: 0.6348 - val_accuracy: 0.7967
# Epoch 13/200
# 314/326 [===========================>..] - ETA: 0s - loss: 0.7773 - accuracy: 0.7410
# Epoch 13: val_accuracy improved from 0.79674 to 0.79891, saving model to weights.best.hdf5
# 326/326 [==============================] - 1s 2ms/step - loss: 0.7776 - accuracy: 0.7399 - val_loss: 0.6299 - val_accuracy: 0.7989
# Epoch 14/200
# 301/326 [==========================>...] - ETA: 0s - loss: 0.7602 - accuracy: 0.7375
# Epoch 14: val_accuracy improved from 0.79891 to 0.80543, saving model to weights.best.hdf5
# 326/326 [==============================] - 1s 3ms/step - loss: 0.7629 - accuracy: 0.7349 - val_loss: 0.6139 - val_accuracy: 0.8054
# Epoch 15/200
# 313/326 [===========================>..] - ETA: 0s - loss: 0.7307 - accuracy: 0.7426
# Epoch 15: val_accuracy did not improve from 0.80543
# 326/326 [==============================] - 1s 2ms/step - loss: 0.7316 - accuracy: 0.7405 - val_loss: 0.6134 - val_accuracy: 0.8000
# Epoch 16/200
# 319/326 [============================>.] - ETA: 0s - loss: 0.7311 - accuracy: 0.7522
# Epoch 16: val_accuracy did not improve from 0.80543
# 326/326 [==============================] - 1s 2ms/step - loss: 0.7272 - accuracy: 0.7541 - val_loss: 0.5949 - val_accuracy: 0.8011
# Epoch 17/200
# 314/326 [===========================>..] - ETA: 0s - loss: 0.7233 - accuracy: 0.7510
# Epoch 17: val_accuracy improved from 0.80543 to 0.81630, saving model to weights.best.hdf5
# 326/326 [==============================] - 1s 3ms/step - loss: 0.7202 - accuracy: 0.7522 - val_loss: 0.5763 - val_accuracy: 0.8163
# Epoch 18/200
# 313/326 [===========================>..] - ETA: 0s - loss: 0.6939 - accuracy: 0.7614
# Epoch 18: val_accuracy improved from 0.81630 to 0.82065, saving model to weights.best.hdf5
# 326/326 [==============================] - 1s 3ms/step - loss: 0.6940 - accuracy: 0.7608 - val_loss: 0.5623 - val_accuracy: 0.8207
# Epoch 19/200
# 306/326 [===========================>..] - ETA: 0s - loss: 0.6945 - accuracy: 0.7667
# Epoch 19: val_accuracy improved from 0.82065 to 0.82717, saving model to weights.best.hdf5
# 326/326 [==============================] - 1s 3ms/step - loss: 0.6947 - accuracy: 0.7660 - val_loss: 0.5500 - val_accuracy: 0.8272
# Epoch 20/200
# 322/326 [============================>.] - ETA: 0s - loss: 0.6757 - accuracy: 0.7731
# Epoch 20: val_accuracy improved from 0.82717 to 0.83261, saving model to weights.best.hdf5
# 326/326 [==============================] - 1s 3ms/step - loss: 0.6755 - accuracy: 0.7726 - val_loss: 0.5352 - val_accuracy: 0.8326
# Epoch 21/200
# 326/326 [==============================] - ETA: 0s - loss: 0.6660 - accuracy: 0.7727
# Epoch 21: val_accuracy improved from 0.83261 to 0.83696, saving model to weights.best.hdf5
# 326/326 [==============================] - 1s 3ms/step - loss: 0.6660 - accuracy: 0.7727 - val_loss: 0.5270 - val_accuracy: 0.8370
# Epoch 22/200
# 310/326 [===========================>..] - ETA: 0s - loss: 0.6467 - accuracy: 0.7756
# Epoch 22: val_accuracy improved from 0.83696 to 0.83804, saving model to weights.best.hdf5
# 326/326 [==============================] - 1s 3ms/step - loss: 0.6447 - accuracy: 0.7750 - val_loss: 0.5178 - val_accuracy: 0.8380
# Epoch 23/200
# 310/326 [===========================>..] - ETA: 0s - loss: 0.6370 - accuracy: 0.7810
# Epoch 23: val_accuracy improved from 0.83804 to 0.84891, saving model to weights.best.hdf5
# 326/326 [==============================] - 1s 3ms/step - loss: 0.6370 - accuracy: 0.7810 - val_loss: 0.5221 - val_accuracy: 0.8489
# Epoch 24/200
# 323/326 [============================>.] - ETA: 0s - loss: 0.6245 - accuracy: 0.7841
# Epoch 24: val_accuracy did not improve from 0.84891
# 326/326 [==============================] - 1s 3ms/step - loss: 0.6269 - accuracy: 0.7843 - val_loss: 0.5044 - val_accuracy: 0.8424
# Epoch 25/200
# 315/326 [===========================>..] - ETA: 0s - loss: 0.6108 - accuracy: 0.7897
# Epoch 25: val_accuracy improved from 0.84891 to 0.85109, saving model to weights.best.hdf5
# 326/326 [==============================] - 1s 3ms/step - loss: 0.6124 - accuracy: 0.7900 - val_loss: 0.4942 - val_accuracy: 0.8511
# Epoch 26/200
# 325/326 [============================>.] - ETA: 0s - loss: 0.6080 - accuracy: 0.7935
# Epoch 26: val_accuracy did not improve from 0.85109
# 326/326 [==============================] - 1s 3ms/step - loss: 0.6083 - accuracy: 0.7933 - val_loss: 0.4901 - val_accuracy: 0.8500
# Epoch 27/200
# 318/326 [============================>.] - ETA: 0s - loss: 0.6136 - accuracy: 0.7911
# Epoch 27: val_accuracy improved from 0.85109 to 0.85761, saving model to weights.best.hdf5
# 326/326 [==============================] - 1s 3ms/step - loss: 0.6135 - accuracy: 0.7917 - val_loss: 0.4845 - val_accuracy: 0.8576
# Epoch 28/200
# 303/326 [==========================>...] - ETA: 0s - loss: 0.5880 - accuracy: 0.7956
# Epoch 28: val_accuracy did not improve from 0.85761
# 326/326 [==============================] - 1s 3ms/step - loss: 0.5905 - accuracy: 0.7931 - val_loss: 0.4817 - val_accuracy: 0.8489
# Epoch 29/200
# 304/326 [==========================>...] - ETA: 0s - loss: 0.5649 - accuracy: 0.8041
# Epoch 29: val_accuracy improved from 0.85761 to 0.85978, saving model to weights.best.hdf5
# 326/326 [==============================] - 1s 3ms/step - loss: 0.5666 - accuracy: 0.8046 - val_loss: 0.4694 - val_accuracy: 0.8598
# Epoch 30/200
# 317/326 [============================>.] - ETA: 0s - loss: 0.5835 - accuracy: 0.8064
# Epoch 30: val_accuracy did not improve from 0.85978
# 326/326 [==============================] - 1s 2ms/step - loss: 0.5854 - accuracy: 0.8054 - val_loss: 0.4679 - val_accuracy: 0.8543
# Epoch 31/200
# 309/326 [===========================>..] - ETA: 0s - loss: 0.5677 - accuracy: 0.8131
# Epoch 31: val_accuracy did not improve from 0.85978
# 326/326 [==============================] - 1s 2ms/step - loss: 0.5669 - accuracy: 0.8129 - val_loss: 0.4735 - val_accuracy: 0.8554
# Epoch 32/200
# 315/326 [===========================>..] - ETA: 0s - loss: 0.5738 - accuracy: 0.8034
# Epoch 32: val_accuracy improved from 0.85978 to 0.86957, saving model to weights.best.hdf5
# 326/326 [==============================] - 1s 3ms/step - loss: 0.5709 - accuracy: 0.8046 - val_loss: 0.4516 - val_accuracy: 0.8696
# Epoch 33/200
# 307/326 [===========================>..] - ETA: 0s - loss: 0.5610 - accuracy: 0.8129
# Epoch 33: val_accuracy did not improve from 0.86957
# 326/326 [==============================] - 1s 3ms/step - loss: 0.5583 - accuracy: 0.8134 - val_loss: 0.4521 - val_accuracy: 0.8674
# Epoch 34/200
# 313/326 [===========================>..] - ETA: 0s - loss: 0.5506 - accuracy: 0.8101
# Epoch 34: val_accuracy did not improve from 0.86957
# 326/326 [==============================] - 1s 2ms/step - loss: 0.5487 - accuracy: 0.8109 - val_loss: 0.4455 - val_accuracy: 0.8674
# Epoch 35/200
# 318/326 [============================>.] - ETA: 0s - loss: 0.5518 - accuracy: 0.8213
# Epoch 35: val_accuracy did not improve from 0.86957
# 326/326 [==============================] - 1s 2ms/step - loss: 0.5519 - accuracy: 0.8207 - val_loss: 0.4428 - val_accuracy: 0.8641
# Epoch 36/200
# 304/326 [==========================>...] - ETA: 0s - loss: 0.5460 - accuracy: 0.8174
# Epoch 36: val_accuracy did not improve from 0.86957
# 326/326 [==============================] - 1s 2ms/step - loss: 0.5515 - accuracy: 0.8163 - val_loss: 0.4481 - val_accuracy: 0.8587
# Epoch 37/200
# 319/326 [============================>.] - ETA: 0s - loss: 0.5546 - accuracy: 0.8168
# Epoch 37: val_accuracy improved from 0.86957 to 0.87717, saving model to weights.best.hdf5
# 326/326 [==============================] - 1s 2ms/step - loss: 0.5537 - accuracy: 0.8169 - val_loss: 0.4501 - val_accuracy: 0.8772
# Epoch 38/200
# 317/326 [============================>.] - ETA: 0s - loss: 0.5154 - accuracy: 0.8283
# Epoch 38: val_accuracy did not improve from 0.87717
# 326/326 [==============================] - 1s 3ms/step - loss: 0.5154 - accuracy: 0.8273 - val_loss: 0.4331 - val_accuracy: 0.8652
# Epoch 39/200
# 312/326 [===========================>..] - ETA: 0s - loss: 0.5201 - accuracy: 0.8275
# Epoch 39: val_accuracy did not improve from 0.87717
# 326/326 [==============================] - 1s 2ms/step - loss: 0.5214 - accuracy: 0.8259 - val_loss: 0.4357 - val_accuracy: 0.8652
# Epoch 40/200
# 317/326 [============================>.] - ETA: 0s - loss: 0.5226 - accuracy: 0.8231
# Epoch 40: val_accuracy did not improve from 0.87717
# 326/326 [==============================] - 1s 2ms/step - loss: 0.5271 - accuracy: 0.8221 - val_loss: 0.4319 - val_accuracy: 0.8663
# Epoch 41/200
# 315/326 [===========================>..] - ETA: 0s - loss: 0.5023 - accuracy: 0.8319
# Epoch 41: val_accuracy did not improve from 0.87717
# 326/326 [==============================] - 1s 2ms/step - loss: 0.5040 - accuracy: 0.8317 - val_loss: 0.4316 - val_accuracy: 0.8652
# Epoch 42/200
# 316/326 [============================>.] - ETA: 0s - loss: 0.5028 - accuracy: 0.8352
# Epoch 42: val_accuracy improved from 0.87717 to 0.87935, saving model to weights.best.hdf5
# 326/326 [==============================] - 1s 3ms/step - loss: 0.5036 - accuracy: 0.8353 - val_loss: 0.4235 - val_accuracy: 0.8793
# Epoch 43/200
# 314/326 [===========================>..] - ETA: 0s - loss: 0.5097 - accuracy: 0.8258
# Epoch 43: val_accuracy did not improve from 0.87935
# 326/326 [==============================] - 1s 3ms/step - loss: 0.5096 - accuracy: 0.8267 - val_loss: 0.4191 - val_accuracy: 0.8652
# Epoch 44/200
# 310/326 [===========================>..] - ETA: 0s - loss: 0.4965 - accuracy: 0.8347
# Epoch 44: val_accuracy did not improve from 0.87935
# 326/326 [==============================] - 1s 2ms/step - loss: 0.4936 - accuracy: 0.8357 - val_loss: 0.4169 - val_accuracy: 0.8750
# Epoch 45/200
# 326/326 [==============================] - ETA: 0s - loss: 0.5063 - accuracy: 0.8349
# Epoch 45: val_accuracy did not improve from 0.87935
# 326/326 [==============================] - 1s 2ms/step - loss: 0.5063 - accuracy: 0.8349 - val_loss: 0.4154 - val_accuracy: 0.8783
# Epoch 46/200
# 314/326 [===========================>..] - ETA: 0s - loss: 0.4876 - accuracy: 0.8336
# Epoch 46: val_accuracy improved from 0.87935 to 0.88370, saving model to weights.best.hdf5
# 326/326 [==============================] - 1s 3ms/step - loss: 0.4848 - accuracy: 0.8345 - val_loss: 0.4124 - val_accuracy: 0.8837
# Epoch 47/200
# 316/326 [============================>.] - ETA: 0s - loss: 0.4947 - accuracy: 0.8291
# Epoch 47: val_accuracy did not improve from 0.88370
# 326/326 [==============================] - 1s 2ms/step - loss: 0.4931 - accuracy: 0.8301 - val_loss: 0.4177 - val_accuracy: 0.8837
# Epoch 48/200
# 310/326 [===========================>..] - ETA: 0s - loss: 0.4896 - accuracy: 0.8389
# Epoch 48: val_accuracy improved from 0.88370 to 0.88478, saving model to weights.best.hdf5
# 326/326 [==============================] - 1s 3ms/step - loss: 0.4896 - accuracy: 0.8378 - val_loss: 0.4051 - val_accuracy: 0.8848
# Epoch 49/200
# 323/326 [============================>.] - ETA: 0s - loss: 0.4828 - accuracy: 0.8388
# Epoch 49: val_accuracy did not improve from 0.88478
# 326/326 [==============================] - 1s 3ms/step - loss: 0.4824 - accuracy: 0.8390 - val_loss: 0.4055 - val_accuracy: 0.8826
# Epoch 50/200
# 323/326 [============================>.] - ETA: 0s - loss: 0.4855 - accuracy: 0.8411
# Epoch 50: val_accuracy did not improve from 0.88478
# 326/326 [==============================] - 1s 2ms/step - loss: 0.4843 - accuracy: 0.8417 - val_loss: 0.4124 - val_accuracy: 0.8804
# Epoch 51/200
# 305/326 [===========================>..] - ETA: 0s - loss: 0.4825 - accuracy: 0.8430
# Epoch 51: val_accuracy improved from 0.88478 to 0.88587, saving model to weights.best.hdf5
# 326/326 [==============================] - 1s 3ms/step - loss: 0.4778 - accuracy: 0.8443 - val_loss: 0.4044 - val_accuracy: 0.8859
# Epoch 52/200
# 322/326 [============================>.] - ETA: 0s - loss: 0.4651 - accuracy: 0.8482
# Epoch 52: val_accuracy improved from 0.88587 to 0.88804, saving model to weights.best.hdf5
# 326/326 [==============================] - 1s 3ms/step - loss: 0.4643 - accuracy: 0.8484 - val_loss: 0.3971 - val_accuracy: 0.8880
# Epoch 53/200
# 324/326 [============================>.] - ETA: 0s - loss: 0.4627 - accuracy: 0.8490
# Epoch 53: val_accuracy did not improve from 0.88804
# 326/326 [==============================] - 1s 3ms/step - loss: 0.4619 - accuracy: 0.8493 - val_loss: 0.3933 - val_accuracy: 0.8870
# Epoch 54/200
# 325/326 [============================>.] - ETA: 0s - loss: 0.4611 - accuracy: 0.8413
# Epoch 54: val_accuracy did not improve from 0.88804
# 326/326 [==============================] - 1s 3ms/step - loss: 0.4607 - accuracy: 0.8415 - val_loss: 0.4060 - val_accuracy: 0.8870
# Epoch 55/200
# 322/326 [============================>.] - ETA: 0s - loss: 0.4700 - accuracy: 0.8434
# Epoch 55: val_accuracy did not improve from 0.88804
# 326/326 [==============================] - 1s 3ms/step - loss: 0.4701 - accuracy: 0.8428 - val_loss: 0.3981 - val_accuracy: 0.8815
# Epoch 56/200
# 311/326 [===========================>..] - ETA: 0s - loss: 0.4620 - accuracy: 0.8505
# Epoch 56: val_accuracy did not improve from 0.88804
# 326/326 [==============================] - 1s 2ms/step - loss: 0.4651 - accuracy: 0.8488 - val_loss: 0.3720 - val_accuracy: 0.8880
# Epoch 57/200
# 309/326 [===========================>..] - ETA: 0s - loss: 0.4514 - accuracy: 0.8509
# Epoch 57: val_accuracy improved from 0.88804 to 0.89022, saving model to weights.best.hdf5
# 326/326 [==============================] - 1s 3ms/step - loss: 0.4483 - accuracy: 0.8526 - val_loss: 0.3806 - val_accuracy: 0.8902
# Epoch 58/200
# 318/326 [============================>.] - ETA: 0s - loss: 0.4349 - accuracy: 0.8506
# Epoch 58: val_accuracy improved from 0.89022 to 0.89130, saving model to weights.best.hdf5
# 326/326 [==============================] - 1s 3ms/step - loss: 0.4344 - accuracy: 0.8511 - val_loss: 0.3801 - val_accuracy: 0.8913
# Epoch 59/200
# 311/326 [===========================>..] - ETA: 0s - loss: 0.4636 - accuracy: 0.8428
# Epoch 59: val_accuracy did not improve from 0.89130
# 326/326 [==============================] - 1s 2ms/step - loss: 0.4622 - accuracy: 0.8447 - val_loss: 0.3752 - val_accuracy: 0.8891
# Epoch 60/200
# 320/326 [============================>.] - ETA: 0s - loss: 0.4406 - accuracy: 0.8543
# Epoch 60: val_accuracy improved from 0.89130 to 0.89348, saving model to weights.best.hdf5
# 326/326 [==============================] - 1s 3ms/step - loss: 0.4409 - accuracy: 0.8539 - val_loss: 0.3743 - val_accuracy: 0.8935
# Epoch 61/200
# 322/326 [============================>.] - ETA: 0s - loss: 0.4317 - accuracy: 0.8533
# Epoch 61: val_accuracy did not improve from 0.89348
# 326/326 [==============================] - 1s 3ms/step - loss: 0.4327 - accuracy: 0.8526 - val_loss: 0.3702 - val_accuracy: 0.8924
# Epoch 62/200
# 307/326 [===========================>..] - ETA: 0s - loss: 0.4399 - accuracy: 0.8502
# Epoch 62: val_accuracy did not improve from 0.89348
# 326/326 [==============================] - 1s 2ms/step - loss: 0.4418 - accuracy: 0.8501 - val_loss: 0.3730 - val_accuracy: 0.8913
# Epoch 63/200
# 312/326 [===========================>..] - ETA: 0s - loss: 0.4432 - accuracy: 0.8576
# Epoch 63: val_accuracy improved from 0.89348 to 0.89565, saving model to weights.best.hdf5
# 326/326 [==============================] - 1s 3ms/step - loss: 0.4445 - accuracy: 0.8566 - val_loss: 0.3776 - val_accuracy: 0.8957
# Epoch 64/200
# 321/326 [============================>.] - ETA: 0s - loss: 0.4415 - accuracy: 0.8573
# Epoch 64: val_accuracy did not improve from 0.89565
# 326/326 [==============================] - 1s 2ms/step - loss: 0.4419 - accuracy: 0.8570 - val_loss: 0.3704 - val_accuracy: 0.8902
# Epoch 65/200
# 307/326 [===========================>..] - ETA: 0s - loss: 0.4445 - accuracy: 0.8544
# Epoch 65: val_accuracy did not improve from 0.89565
# 326/326 [==============================] - 1s 2ms/step - loss: 0.4452 - accuracy: 0.8545 - val_loss: 0.3644 - val_accuracy: 0.8957
# Epoch 66/200
# 312/326 [===========================>..] - ETA: 0s - loss: 0.4323 - accuracy: 0.8584
# Epoch 66: val_accuracy did not improve from 0.89565
# 326/326 [==============================] - 1s 2ms/step - loss: 0.4385 - accuracy: 0.8562 - val_loss: 0.3714 - val_accuracy: 0.8935
# Epoch 67/200
# 301/326 [==========================>...] - ETA: 0s - loss: 0.4382 - accuracy: 0.8540
# Epoch 67: val_accuracy improved from 0.89565 to 0.89891, saving model to weights.best.hdf5
# 326/326 [==============================] - 1s 3ms/step - loss: 0.4321 - accuracy: 0.8560 - val_loss: 0.3694 - val_accuracy: 0.8989
# Epoch 68/200
# 312/326 [===========================>..] - ETA: 0s - loss: 0.4414 - accuracy: 0.8544
# Epoch 68: val_accuracy improved from 0.89891 to 0.90109, saving model to weights.best.hdf5
# 326/326 [==============================] - 1s 2ms/step - loss: 0.4408 - accuracy: 0.8551 - val_loss: 0.3576 - val_accuracy: 0.9011
# Epoch 69/200
# 313/326 [===========================>..] - ETA: 0s - loss: 0.4202 - accuracy: 0.8606
# Epoch 69: val_accuracy did not improve from 0.90109
# 326/326 [==============================] - 1s 2ms/step - loss: 0.4215 - accuracy: 0.8608 - val_loss: 0.3630 - val_accuracy: 0.8967
# Epoch 70/200
# 325/326 [============================>.] - ETA: 0s - loss: 0.4353 - accuracy: 0.8577
# Epoch 70: val_accuracy did not improve from 0.90109
# 326/326 [==============================] - 1s 2ms/step - loss: 0.4350 - accuracy: 0.8576 - val_loss: 0.3601 - val_accuracy: 0.8902
# Epoch 71/200
# 320/326 [============================>.] - ETA: 0s - loss: 0.4404 - accuracy: 0.8578
# Epoch 71: val_accuracy did not improve from 0.90109
# 326/326 [==============================] - 1s 3ms/step - loss: 0.4389 - accuracy: 0.8578 - val_loss: 0.3675 - val_accuracy: 0.8957
# Epoch 72/200
# 326/326 [==============================] - ETA: 0s - loss: 0.4435 - accuracy: 0.8526
# Epoch 72: val_accuracy did not improve from 0.90109
# 326/326 [==============================] - 1s 3ms/step - loss: 0.4435 - accuracy: 0.8526 - val_loss: 0.3584 - val_accuracy: 0.8891
# Epoch 73/200
# 317/326 [============================>.] - ETA: 0s - loss: 0.4324 - accuracy: 0.8608
# Epoch 73: val_accuracy did not improve from 0.90109
# 326/326 [==============================] - 1s 2ms/step - loss: 0.4317 - accuracy: 0.8605 - val_loss: 0.3655 - val_accuracy: 0.8967
# Epoch 74/200
# 305/326 [===========================>..] - ETA: 0s - loss: 0.4123 - accuracy: 0.8666
# Epoch 74: val_accuracy did not improve from 0.90109
# 326/326 [==============================] - 1s 2ms/step - loss: 0.4135 - accuracy: 0.8662 - val_loss: 0.3598 - val_accuracy: 0.8957
# Epoch 75/200
# 318/326 [============================>.] - ETA: 0s - loss: 0.4176 - accuracy: 0.8622
# Epoch 75: val_accuracy did not improve from 0.90109
# 326/326 [==============================] - 1s 3ms/step - loss: 0.4171 - accuracy: 0.8628 - val_loss: 0.3548 - val_accuracy: 0.8913
# Epoch 76/200
# 324/326 [============================>.] - ETA: 0s - loss: 0.4247 - accuracy: 0.8617
# Epoch 76: val_accuracy did not improve from 0.90109
# 326/326 [==============================] - 1s 2ms/step - loss: 0.4233 - accuracy: 0.8622 - val_loss: 0.3527 - val_accuracy: 0.8913
# Epoch 77/200
# 307/326 [===========================>..] - ETA: 0s - loss: 0.4034 - accuracy: 0.8591
# Epoch 77: val_accuracy did not improve from 0.90109
# 326/326 [==============================] - 1s 2ms/step - loss: 0.4011 - accuracy: 0.8605 - val_loss: 0.3591 - val_accuracy: 0.8891
# Epoch 78/200
# 321/326 [============================>.] - ETA: 0s - loss: 0.4079 - accuracy: 0.8657
# Epoch 78: val_accuracy did not improve from 0.90109
# 326/326 [==============================] - 1s 3ms/step - loss: 0.4072 - accuracy: 0.8660 - val_loss: 0.3483 - val_accuracy: 0.8957
# Epoch 79/200
# 321/326 [============================>.] - ETA: 0s - loss: 0.3981 - accuracy: 0.8697
# Epoch 79: val_accuracy did not improve from 0.90109
# 326/326 [==============================] - 1s 3ms/step - loss: 0.4003 - accuracy: 0.8685 - val_loss: 0.3476 - val_accuracy: 0.8946
# Epoch 80/200
# 306/326 [===========================>..] - ETA: 0s - loss: 0.4068 - accuracy: 0.8632
# Epoch 80: val_accuracy did not improve from 0.90109
# 326/326 [==============================] - 1s 3ms/step - loss: 0.4073 - accuracy: 0.8630 - val_loss: 0.3510 - val_accuracy: 0.9011
# Epoch 81/200
# 312/326 [===========================>..] - ETA: 0s - loss: 0.4196 - accuracy: 0.8674
# Epoch 81: val_accuracy did not improve from 0.90109
# 326/326 [==============================] - 1s 2ms/step - loss: 0.4180 - accuracy: 0.8672 - val_loss: 0.3544 - val_accuracy: 0.9011
# Epoch 82/200
# 316/326 [============================>.] - ETA: 0s - loss: 0.4227 - accuracy: 0.8641
# Epoch 82: val_accuracy improved from 0.90109 to 0.90217, saving model to weights.best.hdf5
# 326/326 [==============================] - 1s 3ms/step - loss: 0.4231 - accuracy: 0.8631 - val_loss: 0.3507 - val_accuracy: 0.9022
# Epoch 83/200
# 322/326 [============================>.] - ETA: 0s - loss: 0.4113 - accuracy: 0.8647
# Epoch 83: val_accuracy did not improve from 0.90217
# 326/326 [==============================] - 1s 3ms/step - loss: 0.4095 - accuracy: 0.8653 - val_loss: 0.3413 - val_accuracy: 0.8967
# Epoch 84/200
# 308/326 [===========================>..] - ETA: 0s - loss: 0.3914 - accuracy: 0.8677
# Epoch 84: val_accuracy did not improve from 0.90217
# 326/326 [==============================] - 1s 2ms/step - loss: 0.3878 - accuracy: 0.8687 - val_loss: 0.3419 - val_accuracy: 0.9000
# Epoch 85/200
# 320/326 [============================>.] - ETA: 0s - loss: 0.3941 - accuracy: 0.8703
# Epoch 85: val_accuracy did not improve from 0.90217
# 326/326 [==============================] - 1s 3ms/step - loss: 0.3959 - accuracy: 0.8693 - val_loss: 0.3416 - val_accuracy: 0.8978
# Epoch 86/200
# 322/326 [============================>.] - ETA: 0s - loss: 0.4048 - accuracy: 0.8684
# Epoch 86: val_accuracy did not improve from 0.90217
# 326/326 [==============================] - 1s 3ms/step - loss: 0.4077 - accuracy: 0.8678 - val_loss: 0.3420 - val_accuracy: 0.8978
# Epoch 87/200
# 308/326 [===========================>..] - ETA: 0s - loss: 0.3901 - accuracy: 0.8768
# Epoch 87: val_accuracy improved from 0.90217 to 0.90543, saving model to weights.best.hdf5
# 326/326 [==============================] - 1s 3ms/step - loss: 0.3875 - accuracy: 0.8774 - val_loss: 0.3364 - val_accuracy: 0.9054
# Epoch 88/200
# 322/326 [============================>.] - ETA: 0s - loss: 0.4035 - accuracy: 0.8727
# Epoch 88: val_accuracy did not improve from 0.90543
# 326/326 [==============================] - 1s 3ms/step - loss: 0.4031 - accuracy: 0.8729 - val_loss: 0.3434 - val_accuracy: 0.9011
# Epoch 89/200
# 312/326 [===========================>..] - ETA: 0s - loss: 0.3865 - accuracy: 0.8662
# Epoch 89: val_accuracy did not improve from 0.90543
# 326/326 [==============================] - 1s 2ms/step - loss: 0.3859 - accuracy: 0.8664 - val_loss: 0.3341 - val_accuracy: 0.9033
# Epoch 90/200
# 310/326 [===========================>..] - ETA: 0s - loss: 0.4063 - accuracy: 0.8641
# Epoch 90: val_accuracy did not improve from 0.90543
# 326/326 [==============================] - 1s 2ms/step - loss: 0.4042 - accuracy: 0.8651 - val_loss: 0.3317 - val_accuracy: 0.9022
# Epoch 91/200
# 312/326 [===========================>..] - ETA: 0s - loss: 0.3945 - accuracy: 0.8698
# Epoch 91: val_accuracy did not improve from 0.90543
# 326/326 [==============================] - 1s 3ms/step - loss: 0.3968 - accuracy: 0.8695 - val_loss: 0.3438 - val_accuracy: 0.8870
# Epoch 92/200
# 322/326 [============================>.] - ETA: 0s - loss: 0.3934 - accuracy: 0.8711
# Epoch 92: val_accuracy did not improve from 0.90543
# 326/326 [==============================] - 1s 2ms/step - loss: 0.3941 - accuracy: 0.8708 - val_loss: 0.3294 - val_accuracy: 0.9054
# Epoch 93/200
# 304/326 [==========================>...] - ETA: 0s - loss: 0.4033 - accuracy: 0.8692
# Epoch 93: val_accuracy did not improve from 0.90543
# 326/326 [==============================] - 1s 2ms/step - loss: 0.4008 - accuracy: 0.8702 - val_loss: 0.3457 - val_accuracy: 0.8967
# Epoch 94/200
# 304/326 [==========================>...] - ETA: 0s - loss: 0.4108 - accuracy: 0.8684
# Epoch 94: val_accuracy did not improve from 0.90543
# 326/326 [==============================] - 1s 2ms/step - loss: 0.4055 - accuracy: 0.8695 - val_loss: 0.3346 - val_accuracy: 0.9011
# Epoch 95/200
# 321/326 [============================>.] - ETA: 0s - loss: 0.3828 - accuracy: 0.8721
# Epoch 95: val_accuracy improved from 0.90543 to 0.90870, saving model to weights.best.hdf5
# 326/326 [==============================] - 1s 3ms/step - loss: 0.3828 - accuracy: 0.8718 - val_loss: 0.3293 - val_accuracy: 0.9087
# Epoch 96/200
# 326/326 [==============================] - ETA: 0s - loss: 0.3775 - accuracy: 0.8797
# Epoch 96: val_accuracy did not improve from 0.90870
# 326/326 [==============================] - 1s 2ms/step - loss: 0.3775 - accuracy: 0.8797 - val_loss: 0.3313 - val_accuracy: 0.9011
# Epoch 97/200
# 308/326 [===========================>..] - ETA: 0s - loss: 0.3761 - accuracy: 0.8679
# Epoch 97: val_accuracy did not improve from 0.90870
# 326/326 [==============================] - 1s 3ms/step - loss: 0.3792 - accuracy: 0.8670 - val_loss: 0.3158 - val_accuracy: 0.9033
# Epoch 98/200
# 317/326 [============================>.] - ETA: 0s - loss: 0.3763 - accuracy: 0.8724
# Epoch 98: val_accuracy did not improve from 0.90870
# 326/326 [==============================] - 1s 2ms/step - loss: 0.3754 - accuracy: 0.8726 - val_loss: 0.3355 - val_accuracy: 0.9022
# Epoch 99/200
# 321/326 [============================>.] - ETA: 0s - loss: 0.3613 - accuracy: 0.8806
# Epoch 99: val_accuracy did not improve from 0.90870
# 326/326 [==============================] - 1s 3ms/step - loss: 0.3608 - accuracy: 0.8808 - val_loss: 0.3183 - val_accuracy: 0.9065
# Epoch 100/200
# 322/326 [============================>.] - ETA: 0s - loss: 0.3850 - accuracy: 0.8738
# Epoch 100: val_accuracy did not improve from 0.90870
# 326/326 [==============================] - 1s 2ms/step - loss: 0.3859 - accuracy: 0.8733 - val_loss: 0.3327 - val_accuracy: 0.8978
# Epoch 101/200
# 315/326 [===========================>..] - ETA: 0s - loss: 0.3815 - accuracy: 0.8742
# Epoch 101: val_accuracy did not improve from 0.90870
# 326/326 [==============================] - 1s 2ms/step - loss: 0.3852 - accuracy: 0.8747 - val_loss: 0.3185 - val_accuracy: 0.9022
# Epoch 102/200
# 318/326 [============================>.] - ETA: 0s - loss: 0.3853 - accuracy: 0.8734
# Epoch 102: val_accuracy did not improve from 0.90870
# 326/326 [==============================] - 1s 2ms/step - loss: 0.3835 - accuracy: 0.8743 - val_loss: 0.3403 - val_accuracy: 0.9043
# Epoch 103/200
# 317/326 [============================>.] - ETA: 0s - loss: 0.3818 - accuracy: 0.8695
# Epoch 103: val_accuracy did not improve from 0.90870
# 326/326 [==============================] - 1s 2ms/step - loss: 0.3814 - accuracy: 0.8695 - val_loss: 0.3332 - val_accuracy: 0.9065
# Epoch 104/200
# 326/326 [==============================] - ETA: 0s - loss: 0.3766 - accuracy: 0.8800
# Epoch 104: val_accuracy improved from 0.90870 to 0.91087, saving model to weights.best.hdf5
# 326/326 [==============================] - 1s 3ms/step - loss: 0.3766 - accuracy: 0.8800 - val_loss: 0.3260 - val_accuracy: 0.9109
# Epoch 105/200
# 317/326 [============================>.] - ETA: 0s - loss: 0.3811 - accuracy: 0.8760
# Epoch 105: val_accuracy did not improve from 0.91087
# 326/326 [==============================] - 1s 2ms/step - loss: 0.3812 - accuracy: 0.8750 - val_loss: 0.3186 - val_accuracy: 0.9033
# Epoch 106/200
# 305/326 [===========================>..] - ETA: 0s - loss: 0.3766 - accuracy: 0.8766
# Epoch 106: val_accuracy did not improve from 0.91087
# 326/326 [==============================] - 1s 2ms/step - loss: 0.3763 - accuracy: 0.8791 - val_loss: 0.3215 - val_accuracy: 0.9098
# Epoch 107/200
# 323/326 [============================>.] - ETA: 0s - loss: 0.3673 - accuracy: 0.8820
# Epoch 107: val_accuracy did not improve from 0.91087
# 326/326 [==============================] - 1s 3ms/step - loss: 0.3681 - accuracy: 0.8814 - val_loss: 0.3218 - val_accuracy: 0.9076
# Epoch 108/200
# 324/326 [============================>.] - ETA: 0s - loss: 0.3740 - accuracy: 0.8719
# Epoch 108: val_accuracy did not improve from 0.91087
# 326/326 [==============================] - 1s 3ms/step - loss: 0.3737 - accuracy: 0.8722 - val_loss: 0.3174 - val_accuracy: 0.9076
# Epoch 109/200
# 305/326 [===========================>..] - ETA: 0s - loss: 0.3823 - accuracy: 0.8725
# Epoch 109: val_accuracy improved from 0.91087 to 0.91196, saving model to weights.best.hdf5
# 326/326 [==============================] - 1s 3ms/step - loss: 0.3836 - accuracy: 0.8714 - val_loss: 0.3152 - val_accuracy: 0.9120
# Epoch 110/200
# 309/326 [===========================>..] - ETA: 0s - loss: 0.3538 - accuracy: 0.8809
# Epoch 110: val_accuracy did not improve from 0.91196
# 326/326 [==============================] - 1s 2ms/step - loss: 0.3519 - accuracy: 0.8821 - val_loss: 0.3149 - val_accuracy: 0.9109
# Epoch 111/200
# 307/326 [===========================>..] - ETA: 0s - loss: 0.3875 - accuracy: 0.8772
# Epoch 111: val_accuracy improved from 0.91196 to 0.91413, saving model to weights.best.hdf5
# 326/326 [==============================] - 1s 3ms/step - loss: 0.3931 - accuracy: 0.8747 - val_loss: 0.3069 - val_accuracy: 0.9141
# Epoch 112/200
# 311/326 [===========================>..] - ETA: 0s - loss: 0.3782 - accuracy: 0.8776
# Epoch 112: val_accuracy improved from 0.91413 to 0.91739, saving model to weights.best.hdf5
# 326/326 [==============================] - 1s 3ms/step - loss: 0.3766 - accuracy: 0.8777 - val_loss: 0.3057 - val_accuracy: 0.9174
# Epoch 113/200
# 310/326 [===========================>..] - ETA: 0s - loss: 0.3663 - accuracy: 0.8766
# Epoch 113: val_accuracy did not improve from 0.91739
# 326/326 [==============================] - 1s 2ms/step - loss: 0.3684 - accuracy: 0.8768 - val_loss: 0.3181 - val_accuracy: 0.9065
# Epoch 114/200
# 316/326 [============================>.] - ETA: 0s - loss: 0.3839 - accuracy: 0.8691
# Epoch 114: val_accuracy did not improve from 0.91739
# 326/326 [==============================] - 1s 2ms/step - loss: 0.3810 - accuracy: 0.8704 - val_loss: 0.3189 - val_accuracy: 0.9065
# Epoch 115/200
# 310/326 [===========================>..] - ETA: 0s - loss: 0.3556 - accuracy: 0.8859
# Epoch 115: val_accuracy did not improve from 0.91739
# 326/326 [==============================] - 1s 3ms/step - loss: 0.3526 - accuracy: 0.8866 - val_loss: 0.3273 - val_accuracy: 0.9011
# Epoch 116/200
# 324/326 [============================>.] - ETA: 0s - loss: 0.3590 - accuracy: 0.8791
# Epoch 116: val_accuracy did not improve from 0.91739
# 326/326 [==============================] - 1s 2ms/step - loss: 0.3588 - accuracy: 0.8791 - val_loss: 0.3096 - val_accuracy: 0.9109
# Epoch 117/200
# 317/326 [============================>.] - ETA: 0s - loss: 0.3586 - accuracy: 0.8815
# Epoch 117: val_accuracy did not improve from 0.91739
# 326/326 [==============================] - 1s 2ms/step - loss: 0.3573 - accuracy: 0.8821 - val_loss: 0.3191 - val_accuracy: 0.9087
# Epoch 118/200
# 324/326 [============================>.] - ETA: 0s - loss: 0.3772 - accuracy: 0.8719
# Epoch 118: val_accuracy did not improve from 0.91739
# 326/326 [==============================] - 1s 2ms/step - loss: 0.3763 - accuracy: 0.8722 - val_loss: 0.3100 - val_accuracy: 0.9141
# Epoch 119/200
# 311/326 [===========================>..] - ETA: 0s - loss: 0.3724 - accuracy: 0.8798
# Epoch 119: val_accuracy did not improve from 0.91739
# 326/326 [==============================] - 1s 3ms/step - loss: 0.3655 - accuracy: 0.8818 - val_loss: 0.3106 - val_accuracy: 0.9087
# Epoch 120/200
# 321/326 [============================>.] - ETA: 0s - loss: 0.3737 - accuracy: 0.8785
# Epoch 120: val_accuracy did not improve from 0.91739
# 326/326 [==============================] - 1s 2ms/step - loss: 0.3747 - accuracy: 0.8779 - val_loss: 0.3121 - val_accuracy: 0.9109
# Epoch 121/200
# 316/326 [============================>.] - ETA: 0s - loss: 0.3537 - accuracy: 0.8794
# Epoch 121: val_accuracy did not improve from 0.91739
# 326/326 [==============================] - 1s 2ms/step - loss: 0.3534 - accuracy: 0.8789 - val_loss: 0.3053 - val_accuracy: 0.9109
# Epoch 122/200
# 317/326 [============================>.] - ETA: 0s - loss: 0.3572 - accuracy: 0.8797
# Epoch 122: val_accuracy did not improve from 0.91739
# 326/326 [==============================] - 1s 3ms/step - loss: 0.3583 - accuracy: 0.8798 - val_loss: 0.3086 - val_accuracy: 0.9120
# Epoch 123/200
# 323/326 [============================>.] - ETA: 0s - loss: 0.3499 - accuracy: 0.8853
# Epoch 123: val_accuracy did not improve from 0.91739
# 326/326 [==============================] - 1s 3ms/step - loss: 0.3492 - accuracy: 0.8854 - val_loss: 0.3054 - val_accuracy: 0.9087
# Epoch 124/200
# 318/326 [============================>.] - ETA: 0s - loss: 0.3697 - accuracy: 0.8778
# Epoch 124: val_accuracy did not improve from 0.91739
# 326/326 [==============================] - 1s 2ms/step - loss: 0.3683 - accuracy: 0.8779 - val_loss: 0.3054 - val_accuracy: 0.9141
# Epoch 125/200
# 304/326 [==========================>...] - ETA: 0s - loss: 0.3591 - accuracy: 0.8791
# Epoch 125: val_accuracy did not improve from 0.91739
# 326/326 [==============================] - 1s 2ms/step - loss: 0.3592 - accuracy: 0.8781 - val_loss: 0.3058 - val_accuracy: 0.9152
# Epoch 126/200
# 305/326 [===========================>..] - ETA: 0s - loss: 0.3600 - accuracy: 0.8834
# Epoch 126: val_accuracy did not improve from 0.91739
# 326/326 [==============================] - 1s 2ms/step - loss: 0.3635 - accuracy: 0.8810 - val_loss: 0.3139 - val_accuracy: 0.9076
# Epoch 127/200
# 325/326 [============================>.] - ETA: 0s - loss: 0.3601 - accuracy: 0.8787
# Epoch 127: val_accuracy did not improve from 0.91739
# 326/326 [==============================] - 1s 2ms/step - loss: 0.3601 - accuracy: 0.8785 - val_loss: 0.3046 - val_accuracy: 0.9109
# Epoch 128/200
# 315/326 [===========================>..] - ETA: 0s - loss: 0.3563 - accuracy: 0.8867
# Epoch 128: val_accuracy did not improve from 0.91739
# 326/326 [==============================] - 1s 2ms/step - loss: 0.3549 - accuracy: 0.8879 - val_loss: 0.3037 - val_accuracy: 0.9087
# Epoch 129/200
# 303/326 [==========================>...] - ETA: 0s - loss: 0.3592 - accuracy: 0.8806
# Epoch 129: val_accuracy did not improve from 0.91739
# 326/326 [==============================] - 1s 2ms/step - loss: 0.3552 - accuracy: 0.8808 - val_loss: 0.3132 - val_accuracy: 0.9109
# Epoch 130/200
# 303/326 [==========================>...] - ETA: 0s - loss: 0.3501 - accuracy: 0.8771
# Epoch 130: val_accuracy did not improve from 0.91739
# 326/326 [==============================] - 1s 3ms/step - loss: 0.3565 - accuracy: 0.8766 - val_loss: 0.3082 - val_accuracy: 0.9098
# Epoch 131/200
# 307/326 [===========================>..] - ETA: 0s - loss: 0.3608 - accuracy: 0.8842
# Epoch 131: val_accuracy did not improve from 0.91739
# 326/326 [==============================] - 1s 3ms/step - loss: 0.3625 - accuracy: 0.8843 - val_loss: 0.3064 - val_accuracy: 0.9109
# Epoch 132/200
# 306/326 [===========================>..] - ETA: 0s - loss: 0.3567 - accuracy: 0.8848
# Epoch 132: val_accuracy did not improve from 0.91739
# 326/326 [==============================] - 1s 3ms/step - loss: 0.3600 - accuracy: 0.8843 - val_loss: 0.3459 - val_accuracy: 0.9065

# %%
# Visualize the training history to see whether you're overfitting.
plt.plot(history.history['accuracy'])
plt.plot(history.history['val_accuracy'])
plt.title('Model accuracy')
plt.ylabel('accuracy')
plt.xlabel('epoch')
plt.legend(['TRAIN', 'VAL'], loc='lower right')
plt.show()

# %%
# Evaluate the model using the TEST dataset
loss, accuracy = model.evaluate(X_test, y_test)
# Out:
# 48/48 [==============================] - 0s 2ms/step - loss: 0.3234 - accuracy: 0.8940

# %%
def plot_confusion_matrix(cm, classes,
                          normalize=False,
                          title='Confusion matrix',
                          cmap=plt.cm.Blues):
  """Plots the confusion matrix."""
  if normalize:
    cm = cm.astype('float') / cm.sum(axis=1)[:, np.newaxis]
    print("Normalized confusion matrix")
  else:
    print('Confusion matrix, without normalization')

  plt.imshow(cm, interpolation='nearest', cmap=cmap)
  plt.title(title)
  plt.colorbar()
  tick_marks = np.arange(len(classes))
  plt.xticks(tick_marks, classes, rotation=55)
  plt.yticks(tick_marks, classes)
  fmt = '.2f' if normalize else 'd'
  thresh = cm.max() / 2.
  for i, j in itertools.product(range(cm.shape[0]), range(cm.shape[1])):
    plt.text(j, i, format(cm[i, j], fmt),
              horizontalalignment="center",
              color="white" if cm[i, j] > thresh else "black")

  plt.ylabel('True label')
  plt.xlabel('Predicted label')
  plt.tight_layout()

# Classify pose in the TEST dataset using the trained model
y_pred = model.predict(X_test)

# Convert the prediction result to class name
y_pred_label = [class_names[i] for i in np.argmax(y_pred, axis=1)]
y_true_label = [class_names[i] for i in np.argmax(y_test, axis=1)]

# Plot the confusion matrix
cm = confusion_matrix(np.argmax(y_test, axis=1), np.argmax(y_pred, axis=1))
plot_confusion_matrix(cm,
                      class_names,
                      title ='Confusion Matrix of Pose Classification Model')

# Print the classification report
print('\nClassification Report:\n', classification_report(y_true_label,
                                                          y_pred_label))
# Out:
# 48/48 [==============================] - 0s 2ms/step
# Confusion matrix, without normalization
#
# Classification Report:
#                precision    recall  f1-score   support
#
#       NoPose       0.97      0.69      0.81        52
#        Pose1       0.99      0.93      0.96       238
#        Pose2       0.97      0.87      0.92       221
#        Pose3       0.86      0.98      0.91       219
#        Pose4       0.85      0.97      0.90       216
#        Pose5       0.92      0.88      0.90       196
#        Pose6       0.94      0.74      0.83       158
#        Pose7       0.78      0.89      0.83       228
#
#     accuracy                           0.89      1528
#    macro avg       0.91      0.87      0.88      1528
# weighted avg       0.90      0.89      0.89      1528

# %%
def processTensorImageFromNumpy(image):
    image = tf.convert_to_tensor(image, dtype=tf.float32)
    return image

# def processTensorImage(path):
#     image = tf.io.read_file(path)
#     image = tf.image.decode_jpeg(image)
#     return image

# %%
def classifyPose(image,face):
    poses={"NoPose":"Unknown Pose",
       "Pose1":"Stop vehicles from left and right",
       "Pose2":"Stop from front",
       "Pose3":"Stop vehicles from behind",
       "Pose4":"Start vehicle from left",
       "Pose5":"Start vehicle from right",
       "Pose6":"Start vehicle on T point",
       "Pose7":"Stop vehicles from front and back"}
    image = processTensorImage(image)
    person = detect(image)
    pose_landmarks = np.array([[keypoint.coordinate.x, keypoint.coordinate.y, keypoint.score]
                              for keypoint in person.keypoints], dtype=np.float32)
    coordinates = pose_landmarks.flatten().astype(str).tolist()
    df = pd.DataFrame([coordinates]).reset_index(drop=True)
    X = df.astype('float64').to_numpy()
    X = np.insert(X, 0, face, axis=1)
    X = np.insert(X, 0, face, axis=1)
    X = np.insert(X, 0, face, axis=1)
    y = model.predict(X)
    y_pred = [class_names[i] for i in np.argmax(y, axis=1)]
    return poses[y_pred[0]]

# %%
face_cascade = cv2.CascadeClassifier('haarcascade_frontalface_default.xml')
camera_video = cv2.VideoCapture(0)
camera_video.set(3, 1280)
camera_video.set(4, 960)
cv2.namedWindow('Traffic Sign Classification', cv2.WINDOW_NORMAL)
while camera_video.isOpened():
    ok, frame = camera_video.read()
    time1 = time.time()
    if not ok:
        continue
    gray = cv2.cvtColor(frame, cv2.COLOR_BGR2GRAY)
    faces = face_cascade.detectMultiScale(gray, 1.1, 4)
    face = 1 if len(faces) > 0 else 0
    frame_height, frame_width, _ = frame.shape
    frame = cv2.resize(
        frame, (int(frame_width * (320 / frame_height)), 320))
    pose = classifyPose(frame,face)
    frame = cv2.flip(frame, 1)
    if face == 1:
        face_detected = "Face detected"
    else:
        face_detected = "Face not detected"
    time2 = time.time()
    fps = 0
    if (time2 - time1) > 0:
        fps = 1.0 / (time2 - time1)
    cv2.putText(frame, 'FPS: {}'.format(int(fps)), (500, 15),
                cv2.FONT_HERSHEY_PLAIN, 1, (0, 255, 0), 2)
    cv2.putText(frame, f'POSE: {pose} + {face_detected}', (10, 15),
                cv2.FONT_HERSHEY_PLAIN, 1, (0, 255, 0), 2)
    time1 = time2
    
    cv2.imshow('Traffic Sign Classification', frame)
    k = cv2.waitKey(1) & 0xFF
    if(k == 27):
        break
camera_video.release()
cv2.destroyAllWindows()
